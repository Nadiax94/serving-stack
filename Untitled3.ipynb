# %% [markdown]
# <a href="https://colab.research.google.com/github/Nadiax94/serving-stack/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Aug 26 04:26:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip -q install "transformers==4.46.*" "accelerate==1.1.*"
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 333.2/333.2 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 46.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 81.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gradio 6.24.0 requires huggingface-hub<2.0,>=1.16.0, but you have huggingface-hub 0.36.2 which is incompatible.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !find / -name generate_probe.py 2>/dev/null
# Out:
# /generate_probe.py

# %%
# !python /generate_probe.py
# Out:
# device: cuda (Tesla T4), dtype: torch.float16
# tokenizer_config.json: 7.30kB [00:00, 26.2MB/s]
# vocab.json: 2.78MB [00:00, 80.7MB/s]
# merges.txt: 1.67MB [00:00, 135MB/s]
# tokenizer.json: 7.03MB [00:00, 177MB/s]
# config.json: 100% 660/660 [00:00<00:00, 5.64MB/s]
# 2026-08-26 04:45:13.445959: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors: 100% 3.09G/3.09G [00:33<00:00, 92.7MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.58MB/s]
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# ...

# %%
# !ls /
# Out:
# bin			    home    NGC-DL-CONTAINER-LICENSE  srv
# boot			    kaggle  opt			      sys
# content			    lib     proc		      tmp
# cuda-keyring_1.1-1_all.deb  lib32   python-apt		      tools
# datalab			    lib64   python-apt.tar.xz	      usr
# dev			    libx32  root		      var
# etc			    media   run
# generate_probe.py	    mnt     sbin

# %%
# !find / -name gpu_evidence.json 2>/dev/null
# Out:
# /content/gpu_evidence.json

# %%
from google.colab import files
files.download('/content/gpu_evidence.json')
